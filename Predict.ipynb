# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# !ls checkpoints
# Out:
# checkpoint				yolov3_train_3.tf.data-00000-of-00001
# yolov3_train_1.tf.data-00000-of-00001	yolov3_train_3.tf.index
# yolov3_train_1.tf.index			yolov3_train_4.tf.data-00000-of-00001
# yolov3_train_10.tf.data-00000-of-00001	yolov3_train_4.tf.index
# yolov3_train_10.tf.index		yolov3_train_5.tf.data-00000-of-00001
# yolov3_train_11.tf.data-00000-of-00001	yolov3_train_5.tf.index
# yolov3_train_11.tf.index		yolov3_train_6.tf.data-00000-of-00001
# yolov3_train_12.tf.data-00000-of-00001	yolov3_train_6.tf.index
# yolov3_train_12.tf.index		yolov3_train_7.tf.data-00000-of-00001
# yolov3_train_13.tf.data-00000-of-00001	yolov3_train_7.tf.index
# yolov3_train_13.tf.index		yolov3_train_8.tf.data-00000-of-00001
# yolov3_train_14.tf.data-00000-of-00001	yolov3_train_8.tf.index
# yolov3_train_14.tf.index		yolov3_train_9.tf.data-00000-of-00001
# yolov3_train_2.tf.data-00000-of-00001	yolov3_train_9.tf.index
# yolov3_train_2.tf.index

# %%
# !python3 detect.py 0 --classes /home/ubuntu/VOC2012/voc2012.names \
--num_classes 2 \
--weights checkpoints/yolov3_train_13.tf \
--tfrecord /home/ubuntu/dataset/val/mask.tfrecord \
--output out.jpg
# Out:
# 2021-01-26 02:37:56.703231: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-01-26 02:37:57.608504: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-26 02:37:57.609430: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-26 02:37:57.651179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-26 02:37:57.652039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
img = mpimg.imread('out.jpg')
imgplot = plt.imshow(img)
