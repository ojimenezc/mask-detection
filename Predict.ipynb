# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# !ls
# Out:
# Annotations   JPEGImages    checkpoints   image.jpeg    tfrecord
# ImageSets     Predict.ipynb data          out.jpg

# %% [markdown]
# # Test with the validation tfrecord

# %%
# !python3 /Users/oscar/Documents/repositories/yolov3-tf2/detect.py 0 --classes data/voc2012.names \
--num_classes 2 \
--weights checkpoints/yolov3_train_14.tf \
--tfrecord tfrecord/val/mask.tfrecord \
--output out.jpg

img = mpimg.imread('out.jpg')
imgplot = plt.imshow(img)
# Out:
# 2021-01-26 16:15:20.030870: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-26 16:15:20.037969: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0126 16:15:22.248447 4675608064 detect.py:35] weights loaded
# I0126 16:15:22.248690 4675608064 detect.py:38] classes loaded
# 2021-01-26 16:15:22.401647: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# I0126 16:15:23.004245 4675608064 detect.py:55] time: 0.39498019218444824
# I0126 16:15:23.004354 4675608064 detect.py:57] detections:
# ...

# %% [markdown]
# # Test with specific image

# %%
img = mpimg.imread('image.jpeg')
imgplot = plt.imshow(img)

# %%
# !python3 /Users/oscar/Documents/repositories/yolov3-tf2/detect.py 0 --classes data/voc2012.names \
--num_classes 2 \
--weights checkpoints/yolov3_train_14.tf \
--image image.jpeg \
--output out1.jpg

img = mpimg.imread('out1.jpg')
imgplot = plt.imshow(img)
# Out:
# 2021-01-26 16:13:32.820269: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-26 16:13:32.827551: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0126 16:13:35.133540 4425375232 detect.py:35] weights loaded
# I0126 16:13:35.133807 4425375232 detect.py:38] classes loaded
# I0126 16:13:35.552631 4425375232 detect.py:55] time: 0.3972287178039551
# I0126 16:13:35.552729 4425375232 detect.py:57] detections:
# I0126 16:13:35.564115 4425375232 detect.py:66] output saved to: out1.jpg

# %% [markdown]
# # Test with video

# %%
# !ls
# Out:
# Annotations   Predict.ipynb image.jpeg    tfrecord
# ImageSets     checkpoints   out.jpg       video.mp4
# JPEGImages    data          out1.jpg

# %%
# !python3 /Users/oscar/Documents/repositories/yolov3-tf2/detect_video.py \
  --classes data/voc2012.names \
  --video video.mp4\
  --output video_out.mp4 \
  --output_format 'mp4' \
  --weights checkpoints/yolov3_train_14.tf \
  --num_classes 2
